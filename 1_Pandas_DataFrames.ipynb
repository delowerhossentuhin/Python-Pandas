# %%
import numpy as np
import pandas as pd 
from numpy.random import randn

# %%
my_data=randn(4,3)
my_rows=["A","B","C","D"]
my_cols=["Sunday","Monday","Friday"]

# %%
# Creae DataFrame

# %%
my_df=pd.DataFrame(my_data,my_rows,my_cols)

# %%
my_df
# Out:
#      Sunday    Monday    Friday
# A  0.983061  0.447105  1.030383
# B -0.897855 -1.732335 -0.153537
# C  2.564073  0.340555  0.102895
# D -0.164025 -0.319848  2.064090

# %%
my_data2=np.array([[11,22,33,44],[22,33,44,55],[66,77,88,99]])

# %%
my_rows2=["X","Y","Z"]
my_cols2=["John","Sansa","Arya","Frodo"]

# %%
my_df2=pd.DataFrame(my_data2,my_rows2,my_cols2)

# %%
my_df2
# Out:
#    John  Sansa  Arya  Frodo
# X    11     22    33     44
# Y    22     33    44     55
# Z    66     77    88     99

# %%
# import csv file

# %%
my_df3=pd.read_csv('Customers_100.csv')

# %%
my_df3
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
# Pull Out Rows

# %%
my_df3.loc[0]
# Out:
# Index                                         1
# Customer Id                     DD37Cf93aecA6Dc
# First Name                               Sheryl
# Last Name                                Baxter
# Company                         Rasmussen Group
# City                               East Leonard
# Country                                   Chile
# Phone 1                            229.077.5154
# Phone 2                        397.884.0519x718
# Email                  zunigavanessa@smith.info
# Subscription Date                    2020-08-24
# Website              http://www.stephenson.com/
# Name: 0, dtype: object

# %%
# Pull Out Multiple Rows
# .loc ---> to access data using the row and column labels
# .iloc ---> to access data using integer-based row and column positions

# %%
my_df3.loc[[0,77,9]]
# Out:
#     Index      Customer Id First Name  Last Name                     Company  \
# 0       1  DD37Cf93aecA6Dc     Sheryl     Baxter             Rasmussen Group
# 77     78  FfaeFFbbbf280db    Cassidy    Mcmahon  Mcguire, Huynh and Hopkins
# 9      10  8C2811a503C7c5a   Michelle  Gallagher                Beck-Hendrix
#
#                   City      Country           Phone 1               Phone 2  \
# 0         East Leonard        Chile      229.077.5154      397.884.0519x718
# 77  Lake Sherryborough      Myanmar        5040771311     684-682-0021x1326
# 9           Elaineberg  Timor-Leste  739.218.2516x459  001-054-401-0347x617
#
#                          Email Subscription Date                     Website
# 0     zunigavanessa@smith.info        2020-08-24  http://www.stephenson.com/
# 77  katrinalane@fitzgerald.com        2020-10-21          https://hurst.com/
# 9            mdyer@escobar.net        2021-11-08          https://arias.com/

# %%
my_df3.iloc[[0,77,9]]
# Out:
#     Index      Customer Id First Name  Last Name                     Company  \
# 0       1  DD37Cf93aecA6Dc     Sheryl     Baxter             Rasmussen Group
# 77     78  FfaeFFbbbf280db    Cassidy    Mcmahon  Mcguire, Huynh and Hopkins
# 9      10  8C2811a503C7c5a   Michelle  Gallagher                Beck-Hendrix
#
#                   City      Country           Phone 1               Phone 2  \
# 0         East Leonard        Chile      229.077.5154      397.884.0519x718
# 77  Lake Sherryborough      Myanmar        5040771311     684-682-0021x1326
# 9           Elaineberg  Timor-Leste  739.218.2516x459  001-054-401-0347x617
#
#                          Email Subscription Date                     Website
# 0     zunigavanessa@smith.info        2020-08-24  http://www.stephenson.com/
# 77  katrinalane@fitzgerald.com        2020-10-21          https://hurst.com/
# 9            mdyer@escobar.net        2021-11-08          https://arias.com/

# %%
# Pulling more data out from this csv

# %%
# Grab first 5 rows ---> using head() funciton

# %%
my_df3.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
# Grab Certain number of First Rows

# %%
my_df3.head(7)
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
# 5      6  2d08FB17EE273F4      Aimee     Downs
# 6      7  EA4d384DfDbBf77     Darren      Peck
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
# 5                     Steele Group      Chavezborough
# 6     Lester, Woodard and Mitchell           Lake Ana
#
#                       Country                 Phone 1                Phone 2  \
# ...

# %%
# Grab Last Five rows ---> tail function

# %%
my_df3.tail()
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#                City          Country               Phone 1  \
# 95     East Richard           Guyana   (188)169-1674x58692
# 96     New Bradview        Sri Lanka       +1-846-706-2218
# 97       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 98  Lake Elijahview            Aruba         (530)311-9786
# 99        Judymouth         Honduras         (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 95    001-841-293-3519x614                hhart@jensen.com        2022-01-30
# ...

# %%
# Grab Last Certain number Rows

# %%
my_df3.tail(8)
# Out:
#     Index      Customer Id First Name Last Name                      Company  \
# 92     93  aAb6AFc7AfD0fF3     Collin     Ayers                Lamb-Peterson
# 93     94  54B5B5Fe9F1B6C5     Sherry     Young      Lee, Lucero and Johnson
# 94     95  BE91A0bdcA49Bbc    Darrell   Douglas  Newton, Petersen and Mathis
# 95     96  cb8E23e48d22Eae       Karl     Greer                    Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson        Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra                Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer           Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes           Le, Nash and Cross
#
#                City          Country                Phone 1  \
# 92     South Lonnie         Anguilla       404-645-5351x012
# 93     Frankchester  Solomon Islands           158-687-1764
# 94     Daisyborough             Mali  001-084-845-9524x1777
# ...

# %%
# Get Info about the DataFrame

# %%
my_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    object
#  2   First Name         100 non-null    object
#  3   Last Name          100 non-null    object
#  4   Company            100 non-null    object
#  5   City               100 non-null    object
#  6   Country            100 non-null    object
#  7   Phone 1            100 non-null    object
#  8   Phone 2            100 non-null    object
#  9   Email              100 non-null    object
#  10  Subscription Date  100 non-null    object
#  11  Website            100 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 9.5+ KB

# %%
# Get Shape of Rows and columns

# %%
my_df3.shape
# Out:
# (100, 12)

# %%
# Get Dimension of DataFrame

# %%
my_df3.ndim
# Out:
# 2

# %%
# Get the Columns datatype

# %%
my_df3.dtypes
# Out:
# Index                 int64
# Customer Id          object
# First Name           object
# Last Name            object
# Company              object
# City                 object
# Country              object
# Phone 1              object
# Phone 2              object
# Email                object
# Subscription Date    object
# Website              object
# dtype: object

# %%
# Get Some statistics from DataFrame

# %%
my_df3.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
# Statistics from specific columns

# %%
my_df3['City'].describe()
# Out:
# count              100
# unique             100
# top       East Leonard
# freq                 1
# Name: City, dtype: object

# %%
my_df3['Phone 1'].describe()
# Out:
# count              100
# unique             100
# top       229.077.5154
# freq                 1
# Name: Phone 1, dtype: object

# %%
my_df3['Index'].describe()
# Out:
# count    100.000000
# mean      50.500000
# std       29.011492
# min        1.000000
# 25%       25.750000
# 50%       50.500000
# 75%       75.250000
# max      100.000000
# Name: Index, dtype: float64

# %%
my_df3['First Name'].describe()
# Out:
# count        100
# unique        93
# top       Sheryl
# freq           2
# Name: First Name, dtype: object

# %%
# Select Specific column

# %%
my_df3['First Name']
# Out:
# 0       Sheryl
# 1      Preston
# 2          Roy
# 3        Linda
# 4       Joanna
#         ...
# 95        Karl
# 96        Lynn
# 97        Fred
# 98      Yvonne
# 99    Clarence
# Name: First Name, Length: 100, dtype: object

# %%
my_df3.Email
# Out:
# 0           zunigavanessa@smith.info
# 1                    vmata@colon.com
# 2                beckycarr@hogan.com
# 3        stanleyblackwell@benson.org
# 4            colinalvarado@miles.net
#                    ...
# 95                  hhart@jensen.com
# 96                 vkemp@ferrell.com
# 97                  swagner@kane.org
# 98    mccarthystephen@horn-green.biz
# 99            colleen91@faulkner.biz
# Name: Email, Length: 100, dtype: object

# %%
my_df3.Company
# Out:
# 0                     Rasmussen Group
# 1                         Vega-Gentry
# 2                       Murillo-Perry
# 3     Dominguez, Mcmillan and Donovan
# 4            Martin, Lang and Andrade
#                    ...
# 95                          Carey LLC
# 96              Ware, Burns and Oneal
# 97                      Schmitt-Jones
# 98                 Fitzgerald-Harrell
# 99                 Le, Nash and Cross
# Name: Company, Length: 100, dtype: object

# %%
# Select Specific Row Using Location

# %%
my_df3.iloc[7:25:3]
# Out:
#     Index      Customer Id First Name  Last Name  \
# 7       8  0e04AFde9f225dE      Brett     Mullen
# 10     11  216E205d6eBb815       Carl  Schroeder
# 13     14  A08A8aF8BE9FaD4   Kristine        Cox
# 16     17  a5DC21AE3a21eaA   Caroline      Foley
# 19     20  0F60FF3DdCd7aB0     Joanna       Kirk
# 22     23  2FB0FAA1d429421    Colleen     Howard
#
#                          Company               City           Country  \
# 7   Sanford, Davenport and Giles            Kimport          Bulgaria
# 10    Oconnell, Meza and Everett       Shannonville          Guernsey
# 13                Carpenter-Cook           Jodyberg         Sri Lanka
# 16               Winters-Mendoza  West Adriennestad    Western Sahara
# 19                Mays-Mccormick         Jamesshire  French Polynesia
# 22                Greer and Sons       Brittanyview          Paraguay
#
#                  Phone 1               Phone 2  \
# 7   001-583-352-7197x297      001-333-145-0369
# ...

# %%
# Select Specific Column Using Location

# %%
my_df3.iloc[:,4]
# Out:
# 0                     Rasmussen Group
# 1                         Vega-Gentry
# 2                       Murillo-Perry
# 3     Dominguez, Mcmillan and Donovan
# 4            Martin, Lang and Andrade
#                    ...
# 95                          Carey LLC
# 96              Ware, Burns and Oneal
# 97                      Schmitt-Jones
# 98                 Fitzgerald-Harrell
# 99                 Le, Nash and Cross
# Name: Company, Length: 100, dtype: object

# %%
my_df3.iloc[:,2:5]
# Out:
#    First Name Last Name                          Company
# 0      Sheryl    Baxter                  Rasmussen Group
# 1     Preston    Lozano                      Vega-Gentry
# 2         Roy     Berry                    Murillo-Perry
# 3       Linda     Olsen  Dominguez, Mcmillan and Donovan
# 4      Joanna    Bender         Martin, Lang and Andrade
# ..        ...       ...                              ...
# 95       Karl     Greer                        Carey LLC
# 96       Lynn  Atkinson            Ware, Burns and Oneal
# 97       Fred    Guerra                    Schmitt-Jones
# 98     Yvonne    Farmer               Fitzgerald-Harrell
# 99   Clarence    Haynes               Le, Nash and Cross
#
# [100 rows x 3 columns]

# %%
my_df3.iloc[:,0:6:2]
# Out:
#     Index First Name                          Company
# 0       1     Sheryl                  Rasmussen Group
# 1       2    Preston                      Vega-Gentry
# 2       3        Roy                    Murillo-Perry
# 3       4      Linda  Dominguez, Mcmillan and Donovan
# 4       5     Joanna         Martin, Lang and Andrade
# ..    ...        ...                              ...
# 95     96       Karl                        Carey LLC
# 96     97       Lynn            Ware, Burns and Oneal
# 97     98       Fred                    Schmitt-Jones
# 98     99     Yvonne               Fitzgerald-Harrell
# 99    100   Clarence               Le, Nash and Cross
#
# [100 rows x 3 columns]
